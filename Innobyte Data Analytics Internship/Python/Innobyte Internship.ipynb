# %%
# Loaded the required modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loaded the DataSet CSV file as shown below for task completion
Superstore = pd.read_csv("SampleSuperstore.csv",encoding="utf-8",skiprows=0)

# %%
#Taken a copy of original dataset in order to preserve the DataSet
Superstore_Copy = Superstore.copy()

# %% [markdown]
# **To analyse with respect to time adding
# a Date column with distinct random dates**

# %%
# Generating random dates
Starting_Date = '2024-01-01'
Ending_Date = '2024-12-31'
Number_Of_Rows = len(Superstore_Copy)
Random_Dates = np.random.choice(pd.date_range(start=Starting_Date, end=Ending_Date), Number_Of_Rows)

# Adding the Random_Dates as a new column into Superstore_Copy DataFrame
Superstore_Copy['Date'] = Random_Dates

# Printing the updated Superstore_Copy DataFrame
print(Superstore_Copy)
# Out:
#            Ship_Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
Superstore_Copy
# Out:
#            Ship_Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
Superstore_Copy.head()
# Out:
#         Ship_Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal_Code Region         Category Sub_Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit       Date
# 0      0.00   41.9136 2024-09-02
# ...

# %%
Superstore_Copy.tail()
# Out:
#            Ship_Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal_Code Region         Category Sub_Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit       Date
# 9989       0.2   4.1028 2024-06-16
# ...

# %% [markdown]
# **Total number of records (Rows and Columns ) present in the DataSet**

# %%
Superstore_Copy.shape
# Out:
# (9994, 14)

# %%
#Checking if any null values present in the DataSet
Superstore_Copy.isnull()
# Out:
#       Ship_Mode  Segment  Country   City  State  Postal_Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub_Category  Sales  Quantity  Discount  Profit   Date
# ...

# %% [markdown]
# **Below gives us the information about how many null-values(missing values) each column contains**

# %%
#Checking if any null values present in the DataSet
Superstore_Copy.isnull().sum()
# Out:
# Ship_Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal_Code     0
# Region          0
# Category        0
# Sub_Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# Date            0
# dtype: int64

# %% [markdown]
# **Checking Data types of each column**

# %%
Superstore_Copy.dtypes
# Out:
# Ship_Mode               object
# Segment                 object
# Country                 object
# City                    object
# State                   object
# Postal_Code              int64
# Region                  object
# Category                object
# Sub_Category            object
# Sales                  float64
# Quantity                 int64
# Discount               float64
# Profit                 float64
# Date            datetime64[ns]
# dtype: object

# %% [markdown]
# **Task 1 : Objective to analyze retail sales data to derive insights into customer behavior, popular products, and sales trends**

# %% [markdown]
# **Used information function which gives three main information about Dataset 1) Data Types of each columns**
# **2) Non Null Values information which is basically an indiacation of Missing values and 3) Memory Usage of the DataFrame**

# %%
Information = Superstore_Copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship_Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal_Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub_Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
#  13  Date          9994 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# **Checking if duplicate value exist into DataSet and how many unique record exisits**

# %% [markdown]
# **Unique records in DataSet**

# %%
# Count the number of False values (non-duplicates) or it will count the unique values (Records)
Duplicate = Superstore_Copy.duplicated()
num_unique = (~Duplicate).sum()
num_unique
# Out:
# 9994

# %%
# We can find Duplicate records and Unique records in other ways as well. Because The duplicated() function in pandas is used to 
# identify duplicate rows within a DataFrame. It returns a boolean Series indicating whether each row is a duplicate or not.
# This creates a Series of booleans, with True indicating a duplicate row and False indicating a unique row.
# This creates a Series of booleans, with False indicating a unique row.
Unique = (Superstore_Copy[Superstore_Copy.duplicated() == False])
print(Unique)
# Out:
#            Ship_Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
Unique.shape
# Out:
# (9994, 14)

# %% [markdown]
# **Duplicate records in DataSet**

# %%
# Count the number of True values (Records) (duplicates)
num_duplicates = Superstore_Copy.duplicated().sum()
num_duplicates
# Out:
# 0

# %%
# We can find Duplicate records and Unique records in other ways as well. Because The duplicated() function in pandas is used to 
# identify duplicate rows within a DataFrame. It returns a boolean Series indicating whether each row is a duplicate or not.
# This creates a Series of booleans, with True indicating a duplicate row and False indicating a unique row.
# This creates a Series of booleans, with True indicating a duplicate row.
Duplicate = (Superstore_Copy[Superstore_Copy.duplicated() == True])
print(Duplicate)
# Out:
# Empty DataFrame
# Columns: [Ship_Mode, Segment, Country, City, State, Postal_Code, Region, Category, Sub_Category, Sales, Quantity, Discount, Profit, Date]
# Index: []

# %%
Duplicate.shape
# Out:
# (0, 14)

# %%
# Below nunique Function of pandas gives unique values existing in each column individually
Superstore_Copy.nunique()
# Out:
# Ship_Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal_Code      631
# Region             4
# Category           3
# Sub_Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# Date             366
# dtype: int64

# %%
# Below sum method of pandas gives Total unique values existing in all column
Superstore_Copy.nunique().sum()
# Out:
# 14747

# %%
Superstore_Copy.columns
# Out:
# Index(['Ship_Mode', 'Segment', 'Country', 'City', 'State', 'Postal_Code',
#        'Region', 'Category', 'Sub_Category', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Date'],
#       dtype='object')

# %%
# Renaming two word based column name to single word based by applying hyphen in between
Superstore_Copy.rename(columns={'Ship Mode': 'Ship_Mode','Postal Code':'Postal_Code','Sub-Category':'Sub_Category'}, inplace=True)

# %%
Superstore_Copy.columns
# Out:
# Index(['Ship_Mode', 'Segment', 'Country', 'City', 'State', 'Postal_Code',
#        'Region', 'Category', 'Sub_Category', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Date'],
#       dtype='object')

# %% [markdown]
# **Finding Distinct values each column is having which will be important to know each unique values a column can have**

# %%
Unique_Ship_Mode = Superstore_Copy['Ship_Mode'].unique()
print("Unique values of column Ship_Mode")
print(Unique_Ship_Mode)
# Out:
# Unique values of column Ship_Mode
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']

# %%
Unique_Segment = Superstore_Copy['Segment'].unique()
print("Unique values of column Segment")
print(Unique_Segment)
# Out:
# Unique values of column Segment
# ['Consumer' 'Corporate' 'Home Office']

# %%
Unique_Region = Superstore_Copy['Region'].unique()
print("Unique values of column Region")
print(Unique_Region)
# Out:
# Unique values of column Region
# ['South' 'West' 'Central' 'East']

# %%
Unique_Category = Superstore_Copy['Category'].unique()
print("Unique values of column Category")
print(Unique_Category)
# Out:
# Unique values of column Category
# ['Furniture' 'Office Supplies' 'Technology']

# %%
Unique_Sub_Category = Superstore_Copy['Sub_Category'].unique()
print("Unique values of column Sub_Category")
print(Unique_Sub_Category)
# Out:
# Unique values of column Sub_Category
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']

# %%
Superstore_Copy[['Sales','Quantity','Discount','Profit']].describe(include="all")
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
Positive_Profit = Superstore_Copy[Superstore_Copy['Profit']>0]
Positive_Profit
# Out:
#            Ship_Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5     Standard Class   Consumer  United States      Los Angeles  California
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
Profit = np.positive(Positive_Profit['Profit'].sum())
Profit
# Out:
# 442528.3074

# %%
Negative_Loss = Superstore_Copy[Superstore_Copy['Profit']<0]
Negative_Loss
# Out:
#            Ship_Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9920  Standard Class    Corporate  United States            Bryan
# 9921  Standard Class  Home Office  United States            Akron
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9962     First Class  Home Office  United States          Houston
#
#              State  Postal_Code   Region         Category Sub_Category  \
# 3          Florida        33311    South        Furniture       Tables
# ...

# %%
Loss = Negative_Loss['Profit'].sum()
Loss
# Out:
# -156131.2857

# %%
#Total loss incurred
Total_Loss=np.negative(Negative_Loss['Profit'].sum())
Total_Loss
# Out:
# 156131.2857

# %%
Total_Profit = (np.positive(Positive_Profit['Profit'].sum()) ) - (np.negative(Negative_Loss['Profit'].sum()))
Total_Profit
# Out:
# 286397.0217

# %%
Total_Quantity = Superstore_Copy['Quantity'].sum()

# %%
Total_Quantity
# Out:
# 37873

# %%
Total_Sales = Superstore_Copy['Sales'].sum()

# %%
Total_Sales
# Out:
# 2297200.8603000003

# %%
Total_Discount = Superstore_Copy['Discount'].sum()

# %%
Total_Discount
# Out:
# 1561.09

# %%
Minimum_Sales = Superstore_Copy['Sales'].min()
Minimum_Sales
# Out:
# 0.444

# %%
Maximum_Sales = Superstore_Copy['Sales'].max()
Maximum_Sales
# Out:
# 22638.48

# %% [markdown]
# **In General Analysis of Each Columns present in Superstore Dataset**

# %%
Group_by_Ship_Mode = Superstore_Copy.groupby('Ship_Mode')
Count_Ship_Mode = Group_by_Ship_Mode.size()
Count_Ship_Mode
# Out:
# Ship_Mode
# First Class       1538
# Same Day           543
# Second Class      1945
# Standard Class    5968
# dtype: int64

# %%
Most_Preffered_Shipping_Mode = Count_Ship_Mode.idxmax()
Count_Of_Shipping_Mode = Count_Sub_Category.max()
print(f"Most Preffered Shipping Mode is {Most_Preffered_Shipping_Mode} with total number of shipping in respective mode is ", Count_Of_Shipping_Mode)
# Out:
# Most Preffered Shipping Mode is Standard Class with total number of shipping in respective mode is  1523

# %%
Least_Preferred_Shipping_Mode = Count_Ship_Mode.idxmin()
Count_Of_Shipping_Mode = Count_Sub_Category.min()
print(f"Least Preferred Shipping Mode is {Least_Preferred_Shipping_Mode} with total number of shipping in respective mode is ", Count_Of_Sub_Category)
# Out:
# Least Preferred Shipping Mode is Same Day with total number of shipping in respective mode is  68

# %%
Group_by_Segment = Superstore_Copy.groupby('Segment')
Count_Segment = Group_by_Segment.size()
Count_Segment
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# dtype: int64

# %%
Most_Preffered_Segment_Of_High_Sales = Count_Segment.idxmax()
Count_Of_Segment = Count_Segment.max()
print(f"Most Preffered Segment Of High Sales is {Most_Preffered_Segment_Of_High_Sales} segment with total number of segment  in respective segment is ", Count_Of_Segment)
# Out:
# Most Preffered Segment Of High Sales is Consumer segment with total number of segment  in respective segment is  5191

# %%
Least_Preferred_Segment_Of_Low_Sales = Count_Segment.idxmin()
Count_Of_Segment = Count_Segment.min()
print(f"Least Preferred Segment Of Low Sales is {Least_Preferred_Segment_Of_Low_Sales} with total number of segment in respective segment is ", Count_Of_Segment)
# Out:
# Least Preferred Segment Of Low Sales is Home Office with total number of segment in respective segment is  1783

# %%
Group_by_Region = Superstore_Copy.groupby('Region')
Count_Of_Region = Group_by_Region.size()
Count_Of_Region
# Out:
# Region
# Central    2323
# East       2848
# South      1620
# West       3203
# dtype: int64

# %%
Most_Preffered_Region_Of_High_Sales = Count_Of_Region.idxmax()
Count_Region = Count_Of_Region.max()
print(f"Most Preffered Region Of High Sales is {Most_Preffered_Region_Of_High_Sales} with total number of Region in respective Region is ", Count_Region)
# Out:
# Most Preffered Region Of High Sales is West with total number of Region in respective Region is  3203

# %%
Least_Preferred_Region_Of_Low_Sales = Count_Of_Region.idxmin()
Count_Region = Count_Of_Region.min()
print(f"Least Preferred Region Of Low Sales is {Least_Preferred_Region_Of_Low_Sales} with total number of Region in respective Region is ", Count_Region)
# Out:
# Least Preferred Region Of Low Sales is South with total number of Region in respective Region is  1620

# %%
Group_by_Category = Superstore_Copy.groupby('Category')
Count_Category = Group_by_Category.size()
Count_Category
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# dtype: int64

# %%
Most_Sold_Category = Count_Category.idxmax()
Count_Of_Category = Count_Category.max()
print(f"Most Sold Category is {Most_Sold_Category} Category with total number of Category in respective Category is ", Count_Of_Category)
# Out:
# Most Sold Category is Office Supplies Category with total number of Category in respective Category is  6026

# %%
Least_Sold_Category = Count_Category.idxmin()
Count_Of_Category = Count_Category.min()
print(f"Least Sold Category Of Low Sales is {Least_Sold_Category} with total number of Region in respective Category is ", Count_Of_Category)
# Out:
# Least Sold Category Of Low Sales is Technology with total number of Region in respective Category is  1847

# %%
Group_by_Sub_Category = Superstore_Copy.groupby('Sub_Category')
Count_Sub_Category = Group_by_Sub_Category.size()
Count_Sub_Category
# Out:
# Sub_Category
# Accessories     775
# Appliances      466
# Art             796
# Binders        1523
# Bookcases       228
# Chairs          617
# Copiers          68
# Envelopes       254
# Fasteners       217
# Furnishings     957
# Labels          364
# Machines        115
# Paper          1370
# Phones          889
# Storage         846
# Supplies        190
# Tables          319
# dtype: int64

# %%
Maximum_In_Sub_Category = Count_Sub_Category.idxmax()
Count_Of_Sub_Category = Count_Sub_Category.max()
print(f"The SubCategory product which is higher in count is {Maximum_In_Sub_Category} with count", Count_Of_Sub_Category)
# Out:
# The SubCategory product which is higher in count is Binders with count 1523

# %%
Minimum_In_Sub_Category = Count_Sub_Category.idxmin()
Count_Of_Sub_Category = Count_Sub_Category.min()
print(f"The SubCategory product which is Lowest in count is {Minimum_In_Sub_Category} with count", Count_Of_Sub_Category)
# Out:
# The SubCategory product which is Lowest in count is Copiers with count 68

# %% [markdown]
# **Sub - Category wise analysis**

# %%
# Number of Order Placed in Sub Category 
Superstore_Copy['Sub_Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub_Category, dtype: int64

# %%
# Total sales target comlpeted in each distinct Sub Category
Sales_In_Sub_Category = Superstore_Copy.groupby('Sub_Category')['Sales'].sum().sort_values(ascending=True)
Sales_In_Sub_Category
# Out:
# Sub_Category
# Fasteners        3024.2800
# Labels          12486.3120
# Envelopes       16476.4020
# Art             27118.7920
# Supplies        46673.5380
# Paper           78479.2060
# Furnishings     91705.1640
# Appliances     107532.1610
# Bookcases      114879.9963
# Copiers        149528.0300
# Accessories    167380.3180
# Machines       189238.6310
# Binders        203412.7330
# Tables         206965.5320
# Storage        223843.6080
# Chairs         328449.1030
# Phones         330007.0540
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12, 6))  
Sales_In_Sub_Category.plot(kind='bar', color='cyan')
plt.grid(color = 'black',linewidth = 0.5,axis = 'both',alpha = 0.5)
plt.title('Total Profit by Sub Category')
plt.xlabel('Sub Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=45) 
plt.show()

# %%
# Total profit incurred in each each distinct Sub Category
Total_Profit_Categorywise = Positive_Profit.groupby('Sub_Category')['Profit'].sum().sort_values(ascending=True)
Total_Profit_Categorywise
# Out:
# Sub_Category
# Fasteners        982.7134
# Supplies        1826.5224
# Labels          5546.2540
# Art             6527.7870
# Envelopes       6964.1767
# Bookcases       8679.6500
# Tables         14686.6672
# Furnishings    19550.0570
# Appliances     26767.6466
# Storage        27705.1302
# Machines       33503.4251
# Paper          34053.5693
# Chairs         36471.0076
# Accessories    42867.2622
# Phones         52046.3541
# Copiers        55617.8249
# Binders        68732.2597
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(12, 6))  
Total_Profit_Categorywise.plot(kind='bar', color='magenta')
plt.grid(color = 'black',linewidth = 0.5,axis = 'both',alpha = 0.5)
plt.title('Total Profit by Sub Category')
plt.xlabel('Sub Category')
plt.ylabel('Total Profit')
plt.xticks(rotation=45) 
plt.show()

# %%
# Total Loss incurred in each each distinct Sub Category
Total_Loss_Categorywise = Negative_Loss.groupby('Sub_Category')['Profit'].sum().sort_values(ascending=True)
Total_Loss_Categorywise
# Out:
# Sub_Category
# Binders       -38510.4964
# Tables        -32412.1483
# Machines      -30118.6682
# Bookcases     -12152.2060
# Chairs         -9880.8413
# Appliances     -8629.6412
# Phones         -7530.6235
# Furnishings    -6490.9134
# Storage        -6426.3038
# Supplies       -3015.6219
# Accessories     -930.6265
# Fasteners        -33.1952
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(12, 6))  
Total_Loss_Categorywise.plot(kind='bar', color='blue')
plt.grid(color = 'black',linewidth = 0.5,axis = 'both',alpha = 0.5)
plt.title('Total Loss by Sub Category')
plt.xlabel('Sub Category')
plt.ylabel('Total Loss')
plt.xticks(rotation=45) 
plt.show()

# %%
# Total Discount available in each distinct Sub Category
Total_Discount_Categorywise = Positive_Profit.groupby('Sub_Category')['Discount'].sum().sort_values(ascending=True)
Total_Discount_Categorywise
# Out:
# Sub_Category
# Supplies         8.00
# Tables           8.60
# Machines         9.60
# Bookcases        9.65
# Copiers         11.00
# Fasteners       15.40
# Envelopes       20.40
# Appliances      24.00
# Labels          25.00
# Storage         30.80
# Chairs          38.60
# Furnishings     42.00
# Accessories     42.40
# Art             59.60
# Phones          90.80
# Paper          102.60
# Binders        114.60
# Name: Discount, dtype: float64

# %%
plt.figure(figsize=(12, 6))  
Total_Discount_Categorywise.plot(kind='bar', color='cyan')
plt.grid(color = 'black',linewidth = 0.5,axis = 'both',alpha = 0.5)
plt.title('Total Discount by Sub Category')
plt.xlabel('Sub Category')
plt.ylabel('Total Discount')
plt.xticks(rotation=45) 
plt.show()

# %%
# Top Selling Sub-Category
Maximum_In_Sub_Category = Count_Sub_Category.idxmax()
Count_Of_Sub_Category = Count_Sub_Category.max()
print(f"The Sub Category product which is top selling is : {Maximum_In_Sub_Category} with count",(Count_Of_Sub_Category))

# Lowest Selling Sub-Category
Minimum_In_Sub_Category = Count_Sub_Category.idxmin()
Count_Of_Sub_Category = Count_Sub_Category.min()
print(f"The Sub Category product whose sales worst is : {Minimum_In_Sub_Category} with count",(Count_Of_Sub_Category))
# Out:
# The Sub Category product which is top selling is : Binders with count 1523
# The Sub Category product whose sales worst is : Copiers with count 68

# %% [markdown]
# **Category wise analysis**

# %%
#Number of Order Placed in each category
Number_of_Order_Placed=Superstore_Copy['Category'].value_counts().sort_values(ascending=True)
Number_of_Order_Placed
# Out:
# Technology         1847
# Furniture          2121
# Office Supplies    6026
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(12, 6))  
Number_of_Order_Placed.plot(kind='bar', color='skyblue')
plt.grid(color = 'skyblue',linewidth = 0.5,axis = 'both',alpha = 0.5)
plt.title('Number of Order Placed in each Category')
plt.xlabel('Category')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45) 
plt.show()

# %%
# Analysing sales with respect to each category 
Sales_Categorywise = Superstore_Copy.groupby('Category')['Sales'].sum().sort_values(ascending=True)
Sales_Categorywise
# Out:
# Category
# Office Supplies    719047.0320
# Furniture          741999.7953
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
# Analysing Profit with respect to each category
Profit_Categorywise = Positive_Profit.groupby('Category')['Profit'].sum().sort_values(ascending=True)
Profit_Categorywise
# Out:
# Category
# Furniture           79387.3818
# Office Supplies    179106.0593
# Technology         184034.8663
# Name: Profit, dtype: float64

# %%
# Analysing Loss with respect to each category
Loss_Categorywise = Negative_Loss.groupby('Category')['Profit'].sum().sort_values(ascending=True)
Loss_Categorywise
# Out:
# Category
# Furniture         -60936.1090
# Office Supplies   -56615.2585
# Technology        -38579.9182
# Name: Profit, dtype: float64

# %%
# Analysing Discount with respect to each category
Discount_Categorywise = Superstore_Copy.groupby('Category')['Discount'].sum().sort_values(ascending=True)
Discount_Categorywise
# Out:
# Category
# Technology         244.40
# Furniture          368.89
# Office Supplies    947.80
# Name: Discount, dtype: float64

# %%
# Analysing Quantity with respect to each category
Quantity_Categorywise = Superstore_Copy.groupby('Category')['Quantity'].sum().sort_values(ascending=True)
Quantity_Categorywise
# Out:
# Category
# Technology          6939
# Furniture           8028
# Office Supplies    22906
# Name: Quantity, dtype: int64

# %% [markdown]
# **Region based analysis**

# %%
# Calculating each region's count
Superstore_Copy['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
# Analysing Sales with respect to each region of United States
Sales_Regionwise = Superstore_Copy.groupby('Region')['Sales'].sum().sort_values(ascending=True)
Sales_Regionwise
# Out:
# Region
# South      391721.9050
# Central    501239.8908
# East       678781.2400
# West       725457.8245
# Name: Sales, dtype: float64

# %%
# Analysing Profit with respect to each region of United States
Profit_Regionwise = Positive_Profit.groupby('Region')['Profit'].sum().sort_values(ascending=True)
Profit_Regionwise
# Out:
# Region
# South       74254.2626
# Central     96021.2475
# West       131139.4098
# East       141113.3875
# Name: Profit, dtype: float64

# %%
# Analysing Loss with respect to each region of United States
Loss_Regionwise = Negative_Loss.groupby('Region')['Profit'].sum().sort_values(ascending=True)
Loss_Regionwise
# Out:
# Region
# Central   -56314.8850
# East      -49590.6075
# South     -27504.8323
# West      -22720.9609
# Name: Profit, dtype: float64

# %%
# Analysing Discount with respect to each region of United States
Discount_Regionwise = Superstore_Copy.groupby('Region')['Discount'].sum().sort_values(ascending=True)
Discount_Regionwise
# Out:
# Region
# South      238.55
# West       350.20
# East       414.00
# Central    558.34
# Name: Discount, dtype: float64

# %%
# Analysing Quantity with respect to each region of United States
Quantity_Regionwise = Superstore_Copy.groupby('Region')['Quantity'].sum().sort_values(ascending=True)
Quantity_Regionwise
# Out:
# Region
# South       6209
# Central     8780
# East       10618
# West       12266
# Name: Quantity, dtype: int64

# %% [markdown]
# **Most and Least profitable City in the Region**

# %%
# Analysing profit of each City
Profit_Of_Each_City = Positive_Profit.groupby('City')['Profit'].sum().sort_values(ascending=True)
Profit_Of_Each_City
# Out:
# City
# Jupiter                  0.1548
# Bethlehem                0.7110
# San Luis Obispo          1.1946
# Arlington Heights        1.2348
# Cuyahoga Falls           1.2528
#                         ...
# Detroit              13181.7908
# San Francisco        18849.1535
# Seattle              29541.2676
# Los Angeles          31611.0879
# New York City        66003.0063
# Name: Profit, Length: 513, dtype: float64

# %%
# Top profitable region of United States
Top_Profitable_region = Profit_Regionwise.idxmax()
print(f"The most profitable region of United States is: {Top_Profitable_region}")

# Least profitable region of United States
Least_Profitable_region = Profit_Regionwise.idxmin()
print(f"The Least profitable region of United States is: {Least_Profitable_region}")

# Top profitable city of United States
Top_Profitable_city = Profit_Of_Each_City.idxmax()
print(f"The most profitable city of United States is: {Top_Profitable_city}")

# Least profitable city of United States
Least_Profitable_city = Profit_Of_Each_City.idxmin()
print(f"The Least profitable city of United States is: {Least_Profitable_city}")
# Out:
# The most profitable region of United States is: East
# The Least profitable region of United States is: South
# The most profitable city of United States is: New York City
# The Least profitable city of United States is: Jupiter

# %% [markdown]
# **Shipping mode analysis**

# %%
#Calculating count of each type of shipping mode
Shipping_Mode = Superstore_Copy['Ship_Mode'].value_counts()
Shipping_Mode
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship_Mode, dtype: int64

# %%
# Analysing sales in each shipping mode
Sales_In_Each_Ship_Mode = Superstore_Copy.groupby('Ship_Mode')['Sales'].sum().sort_values(ascending=True)
Sales_In_Each_Ship_Mode
# Out:
# Ship_Mode
# Same Day          1.283631e+05
# First Class       3.514284e+05
# Second Class      4.591936e+05
# Standard Class    1.358216e+06
# Name: Sales, dtype: float64

# %%
# Analysing Profit in each shipping mode
Profit_In_Each_Ship_Mode = Positive_Profit.groupby('Ship_Mode')['Profit'].sum().sort_values(ascending=True)
Profit_In_Each_Ship_Mode
# Out:
# Ship_Mode
# Same Day           24789.8643
# First Class        71630.1108
# Second Class       81671.0083
# Standard Class    264437.3240
# Name: Profit, dtype: float64

# %%
# Analysing Loss in each shipping mode
Loss_In_Each_Ship_Mode = Negative_Loss.groupby('Ship_Mode')['Profit'].sum().sort_values(ascending=True)
Loss_In_Each_Ship_Mode
# Out:
# Ship_Mode
# Standard Class   -100348.5365
# Second Class      -24224.3729
# First Class       -22660.2709
# Same Day           -8898.1054
# Name: Profit, dtype: float64

# %%
# Analysing Discount in each shipping mode
Discount_In_Each_Ship_Mode = Superstore_Copy.groupby('Ship_Mode')['Discount'].sum().sort_values(ascending=True)
Discount_In_Each_Ship_Mode
# Out:
# Ship_Mode
# Same Day           82.75
# First Class       253.17
# Second Class      270.15
# Standard Class    955.02
# Name: Discount, dtype: float64

# %%
# Analysing Quantity in each shipping mode
Quantity_In_Each_Ship_Mode = Superstore_Copy.groupby('Ship_Mode')['Quantity'].sum().sort_values(ascending=True)
Quantity_In_Each_Ship_Mode
# Out:
# Ship_Mode
# Same Day           1960
# First Class        5693
# Second Class       7423
# Standard Class    22797
# Name: Quantity, dtype: int64

# %%
#Most\Least preferred Shipping Mode Analysis
Most_Prefferd_Shipping_Mode = Shipping_Mode.idxmax()
Least_Prefferd_Shipping_Mode = Shipping_Mode.idxmin()
print(f"Most preferred Shipping Mode in United States is : {Most_Prefferd_Shipping_Mode}")
print(f"Least preferred Shipping Mode in United States is : {Least_Prefferd_Shipping_Mode}")
# Out:
# Most preferred Shipping Mode in United States is : Standard Class
# Least preferred Shipping Mode in United States is : Same Day

# %% [markdown]
# **Segment wise Analysis**

# %%
# Calculating count of each segment
Segment_Count = Superstore_Copy['Segment'].value_counts() 
Segment_Count
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
# Segment wise analysis for Sales 
Sales_Segmentwise = Superstore_Copy.groupby('Segment')['Sales'].sum().sort_values(ascending=True)
Sales_Segmentwise
# Out:
# Segment
# Home Office    4.296531e+05
# Corporate      7.061464e+05
# Consumer       1.161401e+06
# Name: Sales, dtype: float64

# %%
# Segment wise analysis for Profit
Profit_Segmentwise = Positive_Profit.groupby('Segment')['Profit'].sum().sort_values(ascending=True)
Profit_Segmentwise
# Out:
# Segment
# Home Office     86697.0454
# Corporate      136766.3416
# Consumer       219064.9204
# Name: Profit, dtype: float64

# %%
# Segment wise analysis for Loss
Loss_Segmentwise = Negative_Loss.groupby('Segment')['Profit'].sum().sort_values(ascending=True)
Loss_Segmentwise
# Out:
# Segment
# Consumer      -84945.7112
# Corporate     -44787.2076
# Home Office   -26398.3669
# Name: Profit, dtype: float64

# %%
# Segment wise analysis for Discount
Discount_Segmentwise = Superstore_Copy.groupby('Segment')['Discount'].sum().sort_values(ascending=True)
Discount_Segmentwise
# Out:
# Segment
# Home Office    262.33
# Corporate      477.85
# Consumer       820.91
# Name: Discount, dtype: float64

# %%
# Segment wise analysis for Quantity
Quantity_Segmentwise = Superstore_Copy.groupby('Segment')['Quantity'].sum().sort_values(ascending=True)
Quantity_Segmentwise
# Out:
# Segment
# Home Office     6744
# Corporate      11608
# Consumer       19521
# Name: Quantity, dtype: int64

# %%
# Plot Segment wise sales
plt.figure(figsize=(4, 3))
plt.pie(Sales_Segmentwise, labels=Sales_Segmentwise.index, autopct='%1.2f%%')
plt.title('Superstore Sales Distribution by Segment')
plt.show()

# %%
plt.figure(figsize=(8, 6))  
Profit_Segmentwise.plot(kind='bar', color='cyan')
plt.grid(color = 'skyblue',linewidth = 0.5,axis = 'both',alpha = 0.5)
plt.title('Profit by Segment')
plt.xlabel('Segment')
plt.ylabel('Profit')
plt.show()

# %%
#Most\Least Profittable Segment Analysis.
Most_Profittable_Segment = Profit_Segmentwise.idxmax()
Least_Profittable_Segment = Profit_Segmentwise.idxmin()
print(f"Most Profittable Segment in United States is : {Most_Profittable_Segment}")
print(f"Least Profittable Segment in United States is : {Least_Profittable_Segment}")
# Out:
# Most Profittable Segment in United States is : Consumer
# Least Profittable Segment in United States is : Home Office

# %% [markdown]
# **State wise analysis**

# %%
# Counting each order in state
State_Count = Superstore_Copy['State'].value_counts()
State_Count
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
# Analysing Sales order State wise in United States
Sales_Statewise = Superstore_Copy.groupby('State')['Sales'].sum().sort_values(ascending=True)
Sales_Statewise
# Out:
# State
# North Dakota               919.9100
# West Virginia             1209.8240
# Maine                     1270.5300
# South Dakota              1315.5600
# Wyoming                   1603.1360
# District of Columbia      2865.0200
# Kansas                    2914.3100
# Idaho                     4382.4860
# Iowa                      4579.7600
# New Mexico                4783.5220
# Montana                   5589.3520
# New Hampshire             7292.5240
# Nebraska                  7464.9300
# South Carolina            8481.7100
# Vermont                   8929.3700
# Louisiana                 9217.0300
# Mississippi              10771.3400
# Utah                     11220.0560
# Arkansas                 11678.1300
# Connecticut              13384.3570
# Nevada                   16729.1020
# Oregon                   17431.1500
# Alabama                  19510.6400
# Oklahoma                 19683.3900
# Missouri                 22205.1500
# Rhode Island             22627.9560
# ...

# %%
# Analysing Profit incurred State wise in United States
Profit_Statewise = Positive_Profit.groupby('State')['Profit'].sum().sort_values(ascending=True)
Profit_Statewise
# Out:
# State
# Wyoming                   100.1960
# North Dakota              230.1497
# West Virginia             262.8752
# South Dakota              394.8283
# Maine                     454.4862
# Idaho                     826.7231
# Kansas                    836.4435
# District of Columbia     1059.5893
# New Mexico               1162.8104
# Iowa                     1183.8119
# Oregon                   1700.0059
# South Carolina           1769.0566
# New Hampshire            1811.8192
# Montana                  1833.3285
# Tennessee                1915.3238
# Nebraska                 2037.0942
# Louisiana                2196.1023
# Vermont                  2244.9783
# Colorado                 2373.0469
# Utah                     2546.5335
# Mississippi              3172.9762
# Arizona                  3228.8429
# Nevada                   3426.3481
# Connecticut              3531.1064
# Arkansas                 4008.6871
# North Carolina           4067.0732
# ...

# %%
# Analysing Loss incurred State wise in United States
Loss_Statewise = Negative_Loss.groupby('State')['Profit'].sum().sort_values(ascending=True)
Loss_Statewise
# Out:
# State
# Texas            -36813.1875
# Ohio             -21750.0002
# Pennsylvania     -21602.8515
# Illinois         -19501.6975
# North Carolina   -11557.9854
# Colorado          -8900.9048
# Florida           -8689.8295
# Tennessee         -7257.0174
# Arizona           -6656.7675
# New York          -5031.1378
# California        -3769.6651
# Oregon            -2890.4764
# Massachusetts      -566.2617
# Washington         -387.8706
# Rhode Island       -230.1678
# Nevada             -109.5822
# New Hampshire      -105.3164
# Delaware            -85.8963
# West Virginia       -76.9536
# Maryland            -71.1170
# New Jersey          -51.2906
# Connecticut         -19.6146
# New Mexico           -5.6943
# Name: Profit, dtype: float64

# %%
# Analysing Discount given State wise in United States
Discount_Statewise = Superstore_Copy.groupby('State')['Discount'].sum().sort_values(ascending=True)
Discount_Statewise
# Out:
# State
# Alabama                   0.00
# Missouri                  0.00
# Maine                     0.00
# Louisiana                 0.00
# Kentucky                  0.00
# Kansas                    0.00
# Iowa                      0.00
# Indiana                   0.00
# Wisconsin                 0.00
# Mississippi               0.00
# Nebraska                  0.00
# North Dakota              0.00
# District of Columbia      0.00
# Oklahoma                  0.00
# South Carolina            0.00
# South Dakota              0.00
# Vermont                   0.00
# Arkansas                  0.00
# Virginia                  0.00
# Georgia                   0.00
# Minnesota                 0.00
# Wyoming                   0.20
# West Virginia             0.30
# New Hampshire             0.30
# Maryland                  0.60
# Connecticut               0.60
# New Jersey                0.60
# Delaware                  0.60
# Montana                   1.00
# Rhode Island              1.20
# ...

# %%
# Analysing Quantites ordered State wise in United States
Quantity_Statewise = Superstore_Copy.groupby('State')['Quantity'].sum().sort_values(ascending=True)
Quantity_Statewise
# Out:
# State
# Wyoming                    4
# West Virginia             18
# North Dakota              30
# Maine                     35
# District of Columbia      40
# South Dakota              42
# Vermont                   50
# Montana                   56
# Idaho                     64
# Kansas                    74
# Iowa                     112
# New Hampshire            127
# Nebraska                 136
# New Mexico               151
# Louisiana                156
# Nevada                   168
# South Carolina           172
# Rhode Island             199
# Utah                     219
# Mississippi              221
# Arkansas                 240
# Oklahoma                 247
# Missouri                 252
# Alabama                  256
# Connecticut              281
# Minnesota                331
# Delaware                 367
# Maryland                 420
# New Jersey               454
# Wisconsin                463
# Massachusetts            491
# Oregon                   499
# ...

# %%
plt.figure(figsize=(8, 15))  
Profit_Statewise.plot(kind='barh', color='green')
plt.title('Profit by State')
plt.xlabel('State')
plt.ylabel('Profit')
plt.show()

# %%
#Most\Least Profittable state in United States
Most_Profittable_State = Profit_Statewise.idxmax()
print(f"The most profitable State in United States is: {Most_Profittable_State}")

# Find the Least profitable State
Least_Profittable_State = Profit_Statewise.idxmin()
print(f"The Least profitable State in United States is: {Least_Profittable_State}")
# Out:
# The most profitable State in United States is: California
# The Least profitable State in United States is: Wyoming

# %% [markdown]
# **Quantity Analysis**

# %% [markdown]
# Lesser number of quantites are having higher count which shows those with less quantities
# are orderred higher number of times then those whose quantities are more, orderred very lesser.

# %%
# Calculating count of quantity to know which is ordered more\less
Quantity_Count = Superstore_Copy['Quantity'].value_counts()
Quantity_Count
# Out:
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: Quantity, dtype: int64

# %% [markdown]
# **Postal code Anaysis**

# %%
# Calculating Postal code countto know who is regular customer
Customer_Count = Superstore_Copy['Postal_Code'].value_counts()
Customer_Count

# %% [markdown]
# In above findings we had observed that Postal code's for which the occurences is more shows
# that Postal code based customer is regular and for few Postal code occurence is merely 1 or 2. The new customer with least occurences of Postal code to make them regular a calculative discount can be offered to them such that they order more.

# %% [markdown]
# **Date Wise analysis**

# %%
Superstore_Copy.head()
# Out:
#         Ship_Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal_Code Region         Category Sub_Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit       Date
# 0      0.00   41.9136 2024-09-02
# ...

# %%
Superstore_Copy.tail()
# Out:
#            Ship_Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal_Code Region         Category Sub_Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit       Date
# 9989       0.2   4.1028 2024-06-16
# ...

# %%
Superstore_Copy.shape
# Out:
# (9994, 14)

# %%
Superstore_Copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship_Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal_Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub_Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
#  13  Date          9994 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
# Total Sales Day wise or on each day sales completed
Daily_Sales = Superstore_Copy.groupby('Date')['Sales'].sum()
print("#Daily Date wise Sales")
print(Daily_Sales)

# Plotting daily sales over time
plt.figure(figsize=(12, 6))
plt.plot(Daily_Sales.index, Daily_Sales.values)
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Superstore Daily Sales')
plt.show()
# Out:
# #Daily Date wise Sales
# Date
# 2024-01-01     6895.8250
# 2024-01-02     2898.6150
# 2024-01-03     9543.4700
# 2024-01-04     2543.5420
# 2024-01-05     6196.7540
#                  ...
# 2024-12-27     4599.8080
# 2024-12-28     4623.1900
# 2024-12-29     1894.8150
# 2024-12-30    11776.5860
# 2024-12-31     5367.4275
# Name: Sales, Length: 366, dtype: float64

# %%
# Analysing Profit made on each day
Profit_On_Each_Day = Positive_Profit.groupby('Date')['Profit'].sum()
Profit_On_Each_Day
# Out:
# Date
# 2024-01-01     955.3649
# 2024-01-02     471.4223
# 2024-01-03    2557.8359
# 2024-01-04     897.7766
# 2024-01-05    1488.9515
#                 ...
# 2024-12-27     744.2570
# 2024-12-28     987.1385
# 2024-12-29     299.8010
# 2024-12-30    2245.4698
# 2024-12-31    1171.2854
# Name: Profit, Length: 366, dtype: float64

# %%
# Plotting daily sales over time
plt.figure(figsize=(12, 6))
plt.plot(Profit_On_Each_Day.index, Daily_Sales.values)
plt.xlabel('Date')
plt.ylabel('Profit')
plt.title('Superstore Daily Profit')
plt.show()

# %%
#Most\Least Profittable Day

#Most Profittable Day
Most_Profittable_Day = Profit_On_Each_Day.idxmax()
print(f"Most Profittable Day is : {Most_Profittable_Day}")

#Least Profittable Day
Least_Profittable_Day = Profit_On_Each_Day.idxmin()
print(f"Least Profittable Day is : {Most_Profittable_Day}")
# Out:
# Most Profittable Day is : 2024-03-17 00:00:00
# Least Profittable Day is : 2024-03-17 00:00:00

# %% [markdown]
# **Monthwise total Sales and Total Profit**

# %%
# Calculating Monthly Sales 
Monthly_Sales = Superstore_Copy.groupby(Superstore_Copy['Date'].dt.to_period('M'))['Sales'].sum().sort_values(ascending=True)
Monthly_Sales
# Out:
# Date
# 2024-02    169658.8634
# 2024-11    175273.5904
# 2024-10    179753.0742
# 2024-09    181982.3775
# 2024-06    183258.0513
# 2024-08    183766.7378
# 2024-04    192974.1668
# 2024-01    194036.1832
# 2024-12    195628.5398
# 2024-05    197259.4599
# 2024-07    217640.1315
# 2024-03    225969.6845
# Freq: M, Name: Sales, dtype: float64

# %%
# Calculating Monthly Discounts
Monthly_Discounts = Superstore_Copy.groupby(Superstore_Copy['Date'].dt.to_period('M'))['Discount'].sum().sort_values(ascending=True)
Monthly_Discounts
# Out:
# Date
# 2024-02    113.92
# 2024-03    116.66
# 2024-04    119.55
# 2024-11    123.09
# 2024-10    123.51
# 2024-06    124.12
# 2024-12    129.84
# 2024-09    130.00
# 2024-01    135.92
# 2024-05    142.17
# 2024-08    146.66
# 2024-07    155.65
# Freq: M, Name: Discount, dtype: float64

# %%
plt.figure(figsize=(8, 8))  
Monthly_Sales.plot(kind='barh', color='skyblue')
plt.title('Total Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %%
# Calculating Monthly Profit 
Monthly_Profit = Superstore_Copy.groupby(Superstore_Copy['Date'].dt.to_period('M'))['Profit'].sum()
Monthly_Profit
# Out:
# Date
# 2024-01    19635.8487
# 2024-02    28841.5077
# 2024-03    33729.8235
# 2024-04    29846.0731
# 2024-05    24671.6440
# 2024-06    25639.7239
# 2024-07    33514.7501
# 2024-08    19818.9174
# 2024-09    17358.0607
# 2024-10    16853.1182
# 2024-11     8523.9599
# 2024-12    27963.5945
# Freq: M, Name: Profit, dtype: float64

# %%
# Plotting Pie chart to analyse profit every month
plt.figure(figsize=(10,8))
plt.pie(Monthly_Profit, labels=Monthly_Profit.index, autopct='%1.2f%%')
plt.title('Superstore Profit Distribution in each month')
plt.show()

# %%
#Most\Least Profittable Month
#Most Profittable Month
Most_Profittable_Month = Monthly_Profit.idxmax()
print(f"The most Profittable Month is: {Most_Profittable_Month}")

#Least Profittable Month
Least_Profittable_Month = Monthly_Profit.idxmin()
print(f"The Least Profittable Month is: {Least_Profittable_Month}")
# Out:
# The most Profittable Month is: 2024-03
# The Least Profittable Month is: 2024-11

# %% [markdown]
# **Total Sales accomplished and Total Profit incurred anually**

# %%
#Analysing total sales completed annualy
Annual_Sales = Superstore_Copy.groupby(Superstore_Copy['Date'].dt.to_period('Y'))['Sales'].sum()
Annual_Sales
# Out:
# Date
# 2024    2.297201e+06
# Freq: A-DEC, Name: Sales, dtype: float64

# %%
#Analysing total profit made annualy
Annual_Profit = Superstore_Copy.groupby(Superstore_Copy['Date'].dt.to_period('Y'))['Profit'].sum()
Annual_Profit
# Out:
# Date
# 2024    286397.0217
# Freq: A-DEC, Name: Profit, dtype: float64

# %%
Negative_Loss[['Discount','Profit']].head()
# Out:
#     Discount     Profit
# 3       0.45  -383.0310
# 14      0.80  -123.8580
# 15      0.80    -3.8160
# 23      0.30    -1.0196
# 27      0.50 -1665.0522

# %% [markdown]
# **Findings**

# %% [markdown]
# I1) Main cause behind not able to make much profit is giving huge discounts which yielded
#     in signficant loss.
# I2) Some regions despite of giving significant amount of discount to lure more customer to make more order did not helped so appropriate advertisement required to make customer aware about the super store.
# I3) Furniture and Office Supplies category is in huge loss, it is due to the reasong of giving more discounts in these categories.
# I4) Customer prefers to Ship in Standard Mode however with this mode of shipping profit is not much so on same day mode discout should be given.
